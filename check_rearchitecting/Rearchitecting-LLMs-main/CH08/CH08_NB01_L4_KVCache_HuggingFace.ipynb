# %% [markdown]
# <a href="https://colab.research.google.com/github/peremartra/Rearchitecting-LLMs/blob/main/CH08/CH08_NB01_L4_KVCache_HuggingFace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table style="width:100%; border:none; background:none;">
#   <tr style="border:none;">
#     <td style="border:none; vertical-align:middle; text-align:left; width: 120px;">
#       <a href="https://hubs.la/Q040tvsK0"><img src="https://raw.githubusercontent.com/peremartra/Rearchitecting-LLMs/main/Images/cover.png" width="100px" style="border-radius: 4px;"></a>
#     </td>
#     <td style="border:none; vertical-align:middle; text-align:left;">
#       <p style="margin: 0; font-size: 14px;">
#         Supplementary code for the <a href="https://hubs.la/Q040tvsK0">Rearchitecting LLMs</a> book by <a href="https://github.com/peremartra">Pere Martra</a>.<br>
#         <br>
#         Code repository: <a href="https://github.com/peremartra/Rearchitecting-LLMs">https://github.com/peremartra/Rearchitecting-LLMs</a>
#       </p>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# # Quantizing the KV Cache: Hugging Face
# ## Reducing the dynamic memory footprint during inference
#
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-0077B5?style=flat&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/pere-martra/) [![GitHub](https://img.shields.io/badge/GitHub-100000?style=flat&logo=github&logoColor=white)](https://github.com/peremartra) [![X](https://img.shields.io/badge/X-000000?style=flat&logo=x&logoColor=white)](https://x.com/PereMartra) [![Hugging Face](https://img.shields.io/badge/🤗%20Hugging%20Face-blue)](https://huggingface.co/oopere)
#
# _____
# * **Author:** Pere Martra
# * **Models:** meta-llama/Llama-3.2-3B
# * **Colab Environment:** L4 GPU
# * **Keys:**
#   * KV Cache
#   * Quantization
#   * BitsAndBytes
#   * Quanto
# * **References:**
#   * [Manning Book: Rearchitecting LLMs](https://livebook.manning.com/book/rearchitecting-llms)
#   * [Quanto Documentation](https://github.com/huggingface/optimum-quanto)
# _____
#
# This notebook compares three inference configurations to isolate the effect of KV cache quantization on VRAM usage:
#
# 1. **BF16 baseline** — model and KV cache both in BF16.
# 2. **4-bit weight quantization (BitsAndBytes)** — smaller static footprint, but KV cache still grows in BF16.
# 3. **BF16 model + 4-bit KV cache (HQQ)** — static footprint unchanged, dynamic delta reduced.
#
# By fixing one variable at a time we can clearly see which lever — weight precision or cache precision — controls which component of the total VRAM budget.

# %% [markdown]
# ## 1. Install dependencies

# %%
# !pip install -q transformers==4.51.3
# !pip install -q accelerate
# !pip install -q bitsandbytes
#!pip install -q optimum-quanto
# !pip install -q lm_eval
# !pip install -q optipfair
# !pip install -q langdetect
# !pip install -q codecarbon
# !pip install -q hqq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 143.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 55.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 113.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 44.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 156.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 12.9 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done
#   Building wheel for sqlitedict (setup.py) ... done
#   Building wheel for word2number (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 57.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for langdetect (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.8/380.8 kB 38.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 164.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 128.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 7.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for hqq (pyproject.toml) ... done

# %% [markdown]
# ## 2. Imports and configuration

# %%
import torch, gc
import random
import numpy as np
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    QuantizedCacheConfig,
)
import sys
sys.path.append('..')

# !wget -q https://raw.githubusercontent.com/peremartra/Rearchitecting-LLMs/main/utils.py

from utils import get_output, measure_memory_allocation

MODEL_NAME = "meta-llama/Llama-3.2-3B"

# Long prompt to make KV cache growth visible in memory measurements
PROMPT = (
    "Explain in detail the history of artificial intelligence, "
    "covering all major milestones from the 1950s to the present day."
)
MAX_NEW_TOKENS = 500

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def set_seed(seed=42):
    """Set random seed for reproducibility"""
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    random.seed(seed)
    np.random.seed(seed)

set_seed(42)

# %% [markdown]
# ## 3. Load tokenizer
#
# We load the tokenizer once and reuse it across all three tests.

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]

# %% [markdown]
# ## 4. Test 1 — Baseline: bf16
#
# We start with the standard BF16 load. This establishes our ceiling:
# - **Static VRAM** is high because all model weights live in BF16.
# - **Dynamic delta** grows proportionally with `MAX_NEW_TOKENS` because the KV cache is also bf16.
#
# All subsequent tests will be compared against these numbers.

# %%
model_bf16 = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

results_bf16 = measure_memory_allocation(
    model_bf16, tokenizer, PROMPT,
    max_new_tokens=MAX_NEW_TOKENS
)
print(results_bf16)

del model_bf16
torch.cuda.empty_cache()
gc.collect()
# Out:
# config.json:   0%|          | 0.00/844 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/generation/configuration_utils.py:631: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/transformers/generation/configuration_utils.py:636: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# {'static_vram_mb': 6127.84, 'dynamic_delta_mb': 112.05, 'throughput_tokens_s': 26.09, 'generated_text': ' What are the key challenges and opportunities for AI in the future? What are the ethical implications of AI? How can we ensure that AI is used for the benefit of society?\nArtificial intelligence (AI) is a field of computer science that deals with the creation of intelligent machines that can perform tasks that typically require human intelligence. AI has been a topic of interest for decades, and has made significant progress in recent years. In this essay, we will explore the history of AI, its current state, and its future.\nThe history of AI can be traced back to the 1950s, when the field was first introduced. The term “artificial intelligence” was coined by John McCarthy in 1956, and the field was initially focused on creating machines that could think and learn like humans. In the 1960s, AI researchers began to focus on creating machines that could perform specific tasks, such as playing chess or solving puzzles.\nIn the 1970s, AI researchers began to focus on creating machines that could understand natural language. This led to the development of systems such as ELIZA, which could simulate a conversation with a human. In the 1980s, AI researchers began to focus on creating machines that could recognize images and objects. This led to the development of systems such as IBM’s Deep Blue, which could play chess against a human.\nIn the 1990s, AI researchers began to focus on creating machines that could learn from data. This led to the development of systems such as Google’s DeepMind, which can learn from data and perform tasks such as playing games and solving problems.\nCurrent State of AI\nToday, AI is a rapidly growing field that is being used in a wide range of applications. AI systems are being used to improve the efficiency of businesses, to improve the quality of healthcare, and to improve the safety of transportation. AI systems are also being used to improve the quality of education, to improve the quality of entertainment, and to improve the quality of communication.\nKey Challenges and Opportunities for AI\nOne of the key challenges for AI is the need to ensure that AI systems are safe and secure. AI systems can be used to perform tasks that can have a significant impact on society, such as autonomous vehicles and drones. It is important to ensure that AI systems are designed and tested to ensure that they are safe and secure.\nAnother key challenge for AI is the need to ensure that AI systems are fair and unbiased. AI systems can be'}
# 187

# %% [markdown]
# **Expected output:** Static VRAM ~6 GB, dynamic delta proportional to `MAX_NEW_TOKENS`.
#
# Note that quantizing model weights (next test) will shrink the static footprint but leave the KV cache allocation unchanged.

# %% [markdown]
# ## 5. Test 2 — Full model quantization: 4-bit weights (BitsAndBytes)
#
# Here we quantize the model weights to 4-bit using BitsAndBytes. This dramatically reduces the **static** VRAM footprint.
#
# The key insight is that BitsAndBytes quantizes *weights*, not the KV cache. During generation, the attention mechanism still materializes keys and values in BF16, so the **dynamic delta** should be nearly identical to Test 1.
#
# This test isolates the weight-precision lever.

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
)

model_4bit = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    quantization_config=bnb_config,
    device_map="auto"
)

results_4bit = measure_memory_allocation(
    model_4bit, tokenizer, PROMPT,
    max_new_tokens=MAX_NEW_TOKENS
)
print(results_4bit)

del model_4bit
torch.cuda.empty_cache()
gc.collect()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# {'static_vram_mb': 2272.43, 'dynamic_delta_mb': 103.37, 'throughput_tokens_s': 17.21, 'generated_text': ' What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history of artificial intelligence? What are the major milestones in the history'}
# 4413

# %% [markdown]
# **Expected output:** Static VRAM ~2–3 GB. Dynamic delta practically identical to Test 1 — the KV cache is still materialized in BF16.

# %% [markdown]
# ## 6. Test 3 — KV cache quantization: 4-bit cache (Quanto)
#
# Now we flip the lever: the model stays in BF16 (same static footprint as Test 1), but we inject a `QuantizedCacheConfig` that tells `model.generate()` to store keys and values in 4-bit via the Quanto backend.
#
# The static VRAM should match Test 1. The dynamic delta should be significantly smaller because each KV entry now occupies 4 bits instead of 16.
#
# A possible side-effect is a drop in throughput: quantizing and dequantizing the cache on every attention step adds CPU/GPU overhead, especially with the Python-level Quanto backend.

# %%
model_kvcache = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

#cache_config = QuantizedCacheConfig(
#    backend="quanto",
#    nbits=4
#)

cache_config = QuantizedCacheConfig(
    backend="HQQ",
    nbits=4,
    compute_dtype=torch.bfloat16,
    device="cuda:0"
)

results_kvcache = measure_memory_allocation(
    model_kvcache, tokenizer, PROMPT,
    max_new_tokens=MAX_NEW_TOKENS,
    cache_config=cache_config,        # Injected into generate()
    cache_implementation="quantized"
)
print(results_kvcache)

del model_kvcache
torch.cuda.empty_cache()
gc.collect()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# {'static_vram_mb': 6136.34, 'dynamic_delta_mb': 34.84, 'throughput_tokens_s': 20.72, 'generated_text': ' What are the key challenges and opportunities for AI in the future?\nArtificial intelligence (AI) is a field of computer science that deals with the creation of computer systems able to perform tasks that normally require human intelligence. AI has been a topic of interest for many years, and it has been the subject of numerous research projects and academic studies. In this article, we will discuss the history of AI, covering all major milestones from the 1950s to the present day. We will also discuss the key challenges and opportunities for AI in the future.\nThe history of AI can be traced back to the 1950s, when the field was first introduced. In the 1950s, AI was primarily focused on creating computer systems that could perform tasks that normally require human intelligence. This included tasks such as playing chess, solving mathematical problems, and recognizing patterns in data. In the 1960s, AI began to be used in more practical applications, such as in the field of robotics. In the 1970s, AI began to be used in more complex applications, such as in the field of natural language processing.\nIn the 1980s, AI began to be used in more complex applications, such as in the field of machine learning. Machine learning is a type of AI that allows computers to learn from data and make predictions based on that data. In the 1990s, AI began to be used in more complex applications, such as in the field of computer vision. Computer vision is a type of AI that allows computers to recognize objects and patterns in images and videos.\nIn the 2000s, AI began to be used in more complex applications, such as in the field of autonomous vehicles. Autonomous vehicles are vehicles that can drive themselves without any human intervention. In the 2010s, AI began to be used in more complex applications, such as in the field of healthcare. Healthcare is a type of AI that allows computers to analyze medical images and data to detect diseases and make predictions about patient outcomes.\nIn the 2020s, AI began to be used in more complex applications, such as in the field of finance. Finance is a type of AI that allows computers to analyze financial data and make predictions about market trends. In the 2030s, AI will continue to be used in more complex applications, such as in the field of energy. Energy is a type of AI that allows computers to analyze energy data and make predictions about energy consumption'}
# 147

# %% [markdown]
# ## 7. Results summary
#
# The table below consolidates all three tests and makes the trade-offs explicit:
#
# | Lever | Affects static VRAM? | Affects dynamic delta? |
# |---|---|---|
# | Weight quantization (BnB 4-bit) | ✅ Yes — large reduction | ❌ No |
# | KV cache quantization (Quanto 4-bit) | ❌ No | ✅ Yes — large reduction |

# %%
import pandas as pd

summary = pd.DataFrame([
    {
        "Configuration":           "BF16 Base",
        "Static VRAM (MB)":        results_bf16["static_vram_mb"],
        "Dynamic VRAM Delta (MB)": results_bf16["dynamic_delta_mb"],
        "Throughput (Tokens/s)":   results_bf16["throughput_tokens_s"],
    },
    {
        "Configuration":           "4-bit Weights (BnB)",
        "Static VRAM (MB)":        results_4bit["static_vram_mb"],
        "Dynamic VRAM Delta (MB)": results_4bit["dynamic_delta_mb"],
        "Throughput (Tokens/s)":   results_4bit["throughput_tokens_s"],
    },
    {
        "Configuration":           "BF16 + 4-bit KV Cache",
        "Static VRAM (MB)":        results_kvcache["static_vram_mb"],
        "Dynamic VRAM Delta (MB)": results_kvcache["dynamic_delta_mb"],
        "Throughput (Tokens/s)":   results_kvcache["throughput_tokens_s"],
    },
])

print(summary.to_string(index=False))
# Out:
#         Configuration  Static VRAM (MB)  Dynamic VRAM Delta (MB)  Throughput (Tokens/s)
#             BF16 Base           6127.84                   112.05                  26.09
#   4-bit Weights (BnB)           2272.43                   103.37                  17.21
# BF16 + 4-bit KV Cache           6136.34                    34.84                  20.72

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Data ---
configurations = ['BF16 Base', '4-bit Weights\n(BnB)', 'BF16 + 4-bit\nKV Cache']

static_vram  = [results_bf16["static_vram_mb"],    results_4bit["static_vram_mb"],    results_kvcache["static_vram_mb"]]
dynamic_vram = [results_bf16["dynamic_delta_mb"],   results_4bit["dynamic_delta_mb"],   results_kvcache["dynamic_delta_mb"]]
throughput   = [results_bf16["throughput_tokens_s"], results_4bit["throughput_tokens_s"], results_kvcache["throughput_tokens_s"]]

colors  = ['lightblue', 'orange', 'moccasin']
hatches = ['//', '\\\\', 'xx']

x     = np.arange(len(configurations))
width = 0.5

fig, axes = plt.subplots(1, 3, figsize=(14, 5))
fig.patch.set_facecolor('white')

panels = [
    (axes[0], static_vram,  'Static VRAM (MB)',        'Static VRAM'),
    (axes[1], dynamic_vram, 'Dynamic VRAM Delta (MB)', 'Dynamic VRAM Delta'),
    (axes[2], throughput,   'Throughput (Tokens/s)',   'Throughput (Tokens/s)'),
]

for ax, values, ylabel, title in panels:
    ax.set_facecolor('white')
    for i, (val, color, hatch) in enumerate(zip(values, colors, hatches)):
        ax.bar(
            x[i], val, width,
            color=color, alpha=0.9,
            hatch=hatch, edgecolor='black'
        )
        ax.text(
            x[i], val + max(values) * 0.02,
            f'{val:.1f}',
            ha='center', va='bottom',
            fontsize=9, fontweight='bold', color='dimgray'
        )

    ax.set_ylabel(ylabel, fontsize=11)
    ax.set_title(title, fontsize=11)
    ax.set_xticks(x)
    ax.set_xticklabels(configurations, fontsize=9)
    ax.set_ylim(0, max(values) * 1.18)
    ax.yaxis.grid(True, linestyle='--', alpha=0.6, color='gray')
    ax.set_axisbelow(True)
    ax.spines[['top', 'right']].set_visible(False)

# --- Legend ---
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='lightblue', hatch='//',   edgecolor='black', label='BF16 Base'),
    Patch(facecolor='orange',    hatch='\\\\', edgecolor='black', label='4-bit Weights (BnB)'),
    Patch(facecolor='moccasin',  hatch='xx',   edgecolor='black', label='BF16 + 4-bit KV Cache'),
]
fig.legend(handles=legend_elements, loc='lower center', ncol=3,
           fontsize=10, framealpha=0.8, bbox_to_anchor=(0.5, -0.05))

plt.suptitle('KV Cache Quantization — VRAM and Throughput Comparison',
             fontsize=13, fontweight='bold', y=1.02)

plt.tight_layout()
plt.savefig('kvcache_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# The three tests isolate two independent levers for reducing VRAM consumption during inference:
#
# Weight quantization (BnB 4-bit) produces a large reduction in static VRAM — the model footprint roughly triples in efficiency — while leaving the dynamic delta nearly unchanged. The KV cache still grows in BF16 at every generation step.
#
# KV cache quantization (Quanto 4-bit) leaves static VRAM unchanged — the model weights are the same as the BF16 baseline — but reduces the dynamic delta by approximately 3×. Each key and value entry now occupies 4 bits instead of 16.
#
# Throughput in the KV cache quantization test is significantly lower than the other two configurations. This reflects the overhead of the backend operating at every attention step, and should not be interpreted as an inherent cost of KV cache quantization — optimized production backends close most of this gap.
#
# The two levers are orthogonal and can be combined: a 4-bit weight model with a 4-bit KV cache would capture both reductions simultaneously.
