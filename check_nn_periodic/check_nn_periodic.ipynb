# %%
import numpy as np
import numpyx as npx
import torch
import torch.nn as nn
import torchx
import torchx.nn as nnx

import matplotlib.pyplot as plt

# %%
s = 12
a1 = .1
b1 = .2
a2 = .3
b2 = .04
a3 = .0
b3 = 2*np.pi/s

t = np.arange(0, 20*s, 1)
y = (a1 + b1*t) + (a2 + b2*t)*np.cos(a3 + b3*t)

# %%
plt.plot(t, y);
